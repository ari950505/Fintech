# %% [markdown]
# **이름: 손민아** **2021.12.28**

# %% [markdown]
# ### 1. A학생의 과목별 점수는 다음과 같다. 평균 점수를 구하여라.
# * 국어:80, 영어:75, 수학:55

# %%
a = 80
b = 75
c = 55
sum = a+b+c
avg = sum/3
print(avg)
# Out:
# 70.0

# %% [markdown]
# ### 2. 자연수 13이 홀수인지 짝수인지 판별할 수 있는 방법에 대해 설명하라.

# %%
if 13 % 2 != 0:
    print("홀수")
else:
    print("짝수")
# Out:
# 홀수

# %% [markdown]
# ### 3. A의 주민등록번호는 881122-1234567이다. A의 주민등록번호를 연월일(yymmdd)부분과 그 뒤의 숫자부분으로 나누어 출력해보자.

# %%
pin = "881122-1234567"
yymmdd = pin.split('-')[0]
num = pin.split('-')[1]
print("주민등록 앞자리:", yymmdd)
print("주민등록 뒷자리:", num)
# Out:
# 주민등록 앞자리: 881122
# 주민등록 뒷자리: 1234567

# %%
pin = "881122-1234567"
yymmdd = pin[0:6]
num = pin[7:]
print("주민등록 앞자리:", yymmdd)
print("주민등록 뒷자리:", num)
# Out:
# 주민등록 앞자리: 881122
# 주민등록 뒷자리: 1234567

# %% [markdown]
# ### 4. 주민등록번호에서 성별을 나타내는 숫자를 출력해 보자.

# %%
print("주민등록성별:", str(num)[0])
# Out:
# 주민등록성별: 1

# %% [markdown]
# ### 5. (1,2,3) 튜플에 값 4를 추가하여 (1,2,3,4)를 만들어 출력해 보자.

# %%
a = (1,2,3)
a = list(a) + [4]
a = tuple(a)
print(a)
# Out:
# (1, 2, 3, 4)

# %%
a = (1,2,3)
a = a + (4,)
print(a)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ### 6. 다음과 같은 딕셔너리 a가 있다.

# %%
a = dict()
a
# Out:
# {}

# %% [markdown]
# ### 다음 중 오류가 발생하는 경우를 고르고, 그 이유를 설명해 보자.

# %%
a['name'] = 'python'

# %%
a[('a',)] = 'python'

# %%
a[[1]] = 'python'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-3976fbf303e6> in <module>
# ----> 1 a[[1]] = 'python'
#
# TypeError: unhashable type: 'list'

# %%
a[250] = 'python'

# %%
오류 발생: a[[1]] = 'python' 

이유: 딕셔너리 값은 어떤 파이썬 객체라도 사용할 수 있지만 딕셔너리 키는 스칼라형 혹은 튜플처럼 
값이 바뀌지 않는 immutable 객체만 사용 가능한데 보기에서 사용한 키 [1] 리스트는 mutable 객체이므로 오류가 발생했다.
# Out:
#   File "<ipython-input-60-f190ab82d1b4>", line 1
#     오류 발생: a[[1]] = 'python'
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 7. [1, 3, 5, 4, 2] 리스트를 [5, 4, 3, 2, 1]로 만들어 보자.

# %%
a = [1, 3, 5, 4, 2]
a = sorted(a)
a.reverse()
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ### 8. 파이썬은 다음처럼 동일한 값에 여러 개의 변수를 선언할 수 있다. 다음과 같이 a, b 변수를 선언한 후 a의 두 번째 요솟값을 변경하면 b 값은 어떻게 될까? 그리고 이런 결과가 나오는 이유에 대해 설명해 보자.

# %%
a = b = [1,2,3]
a[1] = 4
print(b)
# Out:
# [1, 4, 3]

# %%
이유: 파이썬에서 " = " 부호는 변수에 값을 할당한다는 의미를 나타낸다. 
그러므로, a와 b 변수는 모두 동일한 [1, 2, 3]이라는 리스트 객체룰 가리키기 때문에 위와 같이 a 요소값 변경 시 b 의 결과값은 [1,4,3]이 나온다.
# Out:
#   File "<ipython-input-63-81360ab42c82>", line 1
#     이유: 파이썬에서 " = " 부호는 변수에 값을 할당한다는 의미를 나타낸다.
#               ^
# SyntaxError: invalid syntax
